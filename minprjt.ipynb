# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavanighanta24/FSD-/blob/main/minprjt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

number = random.randint(1,10)

guess = int(input("Guess a number between 1 and 10: "))

if guess == number:
    print("Correct! You guessed it.")
else:
    print("Wrong! The number was", number)
# Out:
# Guess a number between 1 and 10: 1
# Wrong! The number was 2
